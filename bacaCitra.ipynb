# %% [markdown]
# <a href="https://colab.research.google.com/github/esa-prakasa/OpenCV_Python_Course/blob/master/bacaCitra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Membuka data yang tersimpan di dalam Google Collaboration.

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/My Drive/Colab Notebooks/OpenCVPython/imagefolder/"

# %%
img = cv2.imread(path+fileName,0)

print(type(gray))

plt.imshow(img,cmap='gray')
plt.show()
# Out:
# <class 'numpy.ndarray'>
